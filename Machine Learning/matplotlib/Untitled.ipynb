# %%
import matplotlib.pyplot as plt
from  matplotlib.image import imread

# %%
a=imread("ab.jpeg")

# %%
a
# Out:
# array([[[ 16,  18,  15],
#         [ 16,  18,  15],
#         [ 16,  18,  15],
#         ...,
#         [153, 154, 148],
#         [153, 154, 148],
#         [152, 153, 147]],
#
#        [[ 16,  18,  15],
#         [ 16,  18,  15],
#         [ 16,  18,  15],
#         ...,
#         [152, 153, 147],
#         [152, 153, 147],
#         [152, 153, 147]],
#
#        [[ 16,  18,  15],
#         [ 16,  18,  15],
#         [ 16,  18,  15],
#         ...,
#         [152, 153, 148],
#         [152, 153, 148],
#         [151, 152, 147]],
#
#        ...,
#
#        [[ 30,  30,  22],
#         [ 30,  30,  22],
#         [ 29,  29,  21],
#         ...,
#         [188, 187, 182],
#         [188, 187, 182],
#         [188, 187, 182]],
#
#        [[ 30,  30,  22],
#         [ 29,  29,  21],
#         [ 27,  27,  19],
#         ...,
#         [187, 186, 181],
#         [187, 186, 181],
#         [187, 186, 181]],
#
#        [[ 29,  29,  21],
#         [ 28,  28,  20],
#         [ 27,  27,  19],
#         ...,
#         [187, 186, 181],
#         [186, 185, 180],
#         [186, 185, 180]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.imshow(a)

# %%
import numpy as np
np.random.seed(1)
x=np.random.randint(0,3,10)
y=np.random.randint(0,3,10)
figure =plt.figure ()
subplots = figure.add_subplot()
plt.plot(x,y)
plt.title('A Rough Diagram ')
plt.xlabel('x-axis ')
plt.ylabel(' y-axis')
plt.show()
