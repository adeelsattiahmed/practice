# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(5)

# %%
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
c=["r",'g',"b",'y']

# %%
x.shape
# Out:
# (5,)

# %%
y=np.random.randint(10,size=(5,))

# %%
y
# Out:
# array([2, 4, 2, 4, 5])

# %%
y.shape
# Out:
# (5,)

# %%
plt.plot(x,y,'-g')

# %%
plt.plot(x,y,'bo')

# %%
plt.plot(x,y,'bo-')

# %%
plt.plot(x,y,'ro-')

# %%
plt.plot(x,y,'g*')

# %%
plt.plot(x,y,'g+')

# %%
plt.plot(x,y,'r^')

# %%
plt.plot(x,y,"r+")

# %%
plt.plot(x,y,'o-')

# %%
plt.plot(x,y,'ro',)
