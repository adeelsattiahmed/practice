# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pn 
import numpy as np
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23608\1317598566.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pn

# %%
x=[1,2,3,4]
y=[23,43,54,32]

# %%
plt.plot(x,y)

# %%
plt.show(x,y)

# %% [markdown]
# ## Methods for plot

# %%
fig= plt.figure() 
room=fig.add_subplot(x)
room.plt()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 fig= plt.figure()
#       2 room=fig.add_subplot(x)
# ----> 3 room.plt()
#       4 plt.show()
#
# AttributeError: 'Axes' object has no attribute 'plt'

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as s
df=s.load_dataset("titanic")

# %%
s.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df=df.drop(['age','deck'], axis =1)

# %%
s.heatmap(df.isna())
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
df[df.isna().any(axis=1)]
# Out:
#      survived  pclass     sex  sibsp  parch  fare embarked  class    who  \
# 61          1       1  female      0      0  80.0      NaN  First  woman
# 829         1       1  female      0      0  80.0      NaN  First  woman
#
#      adult_male embark_town alive  alone
# 61        False         NaN   yes   True
# 829       False         NaN   yes   True

# %%
df=df.dropna()

# %%
s.heatmap(df.isna(),color='blue')
# Out:
# <Axes: >

# %%
plt.bar(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plt.bar(df)
#
# TypeError: bar() missing 1 required positional argument: 'height'
