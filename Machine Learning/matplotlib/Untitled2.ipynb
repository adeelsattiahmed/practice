# %%
import numpy as np 
import matplotlib.pyplot as plt 
x=np.arange(5)
np.random.seed(0)
y=np.random.randint(1,100,size=(5,))
u=[20,30,350,200,400]
fig,((a,b),(c,d),(e,f))=plt.subplots(nrows=3,ncols=2,figsize=(30,30))
a.plot(x,y,'ro-',label='Line plot',kind='Bar')
a.set(xlabel="X_axis",ylabel="Y_axis",title="Plot 1")
a.legend()
a.grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 8
#       6 u=[20,30,350,200,400]
#       7 fig,((a,b),(c,d),(e,f))=plt.subplots(nrows=3,ncols=2,figsize=(30,30))
# ----> 8 a.plot(x,y,'ro-',label='Line plot',kind='Bar')
#       9 a.set(xlabel="X_axis",ylabel="Y_axis",title="Plot 1")
#      10 a.legend()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1721, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1478 """
#    1479 Plot y versus x as lines and/or markers.
#    1480
#    (...)
#    1718 (``'green'``) or hex strings (``'#008000'``).
#    1719 """
#    1720 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1721 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1722 for line in lines:
#    1723     self.add_line(line)
#
# ...
