# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=['C','C++','Python','Javascript','Artficial Intelligence']
c=[0,0,0,0,0.1]
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x20815611dd0>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, ''),
#   Text(0.7360436312779136, 0.817459340184711, ''),
#   Text(-0.33991877217145816, 1.046162142464278, ''),
#   Text(-1.0759623315431446, -0.2287029975759841, ''),
#   Text(0.5500001932481627, -0.9526278325909777, '')])

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=['C','C++','Python','Javascript','Artficial Intelligence']
c=[0,0,0,0,0.1]
plt.pie(x,labels=y)
# Out:
# ([<matplotlib.patches.Wedge at 0x2081554c1d0>,
# ...
#  [Text(1.075962358309037, 0.22870287165240302, 'C'),
#   Text(0.7360436312779136, 0.817459340184711, 'C++'),
#   Text(-0.33991877217145816, 1.046162142464278, 'Python'),
#   Text(-1.0759623315431446, -0.2287029975759841, 'Javascript'),
#   Text(0.5500001932481627, -0.9526278325909777, 'Artficial Intelligence')])

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=['C','C++','Python','Javascript','Artficial Intelligence']
c=[0,0,0,0,0.1]
plt.pie(x,labels=y,explode=c)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=['C','C++','Python','Javascript','Artficial Intelligence']
c=[0,0,0,0,0.1]
plt.pie(x,labels=y,explode=c,radius=1.3)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=['C','C++','Python','Javascript','Artficial Intelligence']
c=[0,0,0,0,0.1]
plt.pie(x,labels=y,explode=c,autopct="%0.1f%%")
plt.legend(loc=0)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=['C','C++','Python','Javascript','Artficial Intelligence']
c=[0,0,0,0,0.1]
plt.pie(x,labels=y,explode=c,autopct="%0.1f%%",radius=1.5,labeldistance=1.1,center=(0,1),textprops={'fontsize':15})
plt.legend(loc=3)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=['C','C++','Python','Javascript','Artficial Intelligence']
c=[0,0,0,0,0.1]
plt.pie(x,labels=y,explode=c,autopct="%0.1f%%",radius=1.5,labeldistance=1.1,center=(0,1),textprops={'fontsize':15})
plt.legend(loc=3)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40,50]
y=['C','C++','Python','Javascript','Artficial Intelligence']
c=[0,0,0,0,0.1]
plt.pie(x,labels=y,explode=c,autopct="%0.1f%%",radius=1.5,labeldistance=1.1,center=(0,1),textprops={'fontsize':15})
plt.pie([1],colors='w',labeldistance=1.1,center=(0,1))
plt.legend(loc=3)
plt.show()
