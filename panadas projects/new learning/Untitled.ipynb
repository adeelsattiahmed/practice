# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pn

# %%
series = pn.Series(["pakistan" , "india" , "nepal"])

# %%
series
# Out:
# 0    pakistan
# 1       india
# 2       nepal
# dtype: object

# %%
data=pn.read_csv('heart_failure_clinical_records_dataset.csv')

# %%
data =data[data['age']>40]

# %%
data
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
data.to_csv('over_40.csv',index=False)

# %%
over_40=pn.read_csv('over_40.csv')

# %%
over_40
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 287  62.0        0                        61         1                 38
# 288  55.0        0                      1820         0                 38
# 289  45.0        0                      2060         1                 60
# 290  45.0        0                      2413         0                 38
# 291  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
over_40.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
over_40.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       292 non-null    float64
#  1   anaemia                   292 non-null    int64
#  2   creatinine_phosphokinase  292 non-null    int64
#  3   diabetes                  292 non-null    int64
#  4   ejection_fraction         292 non-null    int64
#  5   high_blood_pressure       292 non-null    int64
#  6   platelets                 292 non-null    float64
#  7   serum_creatinine          292 non-null    float64
#  8   serum_sodium              292 non-null    int64
#  9   sex                       292 non-null    int64
#  10  smoking                   292 non-null    int64
#  11  time                      292 non-null    int64
#  12  DEATH_EVENT               292 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 29.8 KB

# %%
over_40.describe()
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  292.000000  292.000000                292.000000  292.000000
# mean    61.333336    0.434932                588.089041    0.421233
# std     11.584410    0.496599                980.459212    0.494604
# min     41.000000    0.000000                 23.000000    0.000000
# 25%     52.000000    0.000000                117.250000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         292.000000           292.000000     292.000000
# mean           38.123288             0.356164  263380.310788
# std            11.954030             0.479687   98862.940649
# min            14.000000             0.000000   25100.000000
# ...

# %%
# total number of patients died to heart failure
over_40['DEATH_EVENT'].sum()
# Out:
# 96

# %%
over_40['DEATH_EVENT'].mean()
# Out:
# 0.3287671232876712

# %%
over_40.mean()
# Out:
# age                             61.333336
# anaemia                          0.434932
# creatinine_phosphokinase       588.089041
# diabetes                         0.421233
# ejection_fraction               38.123288
# high_blood_pressure              0.356164
# platelets                   263380.310788
# serum_creatinine                 1.404692
# serum_sodium                   136.599315
# sex                              0.647260
# smoking                          0.321918
# time                           128.630137
# DEATH_EVENT                      0.328767
# dtype: float64

# %%
#checking  that is there any null values
over_40.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
over_40.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
over_40.iloc[:3]
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1

# %%
over_40['DEATH_EVENT'].plot()
# Out:
# <Axes: >

# %%
plt.scatter(x=over_40['age'],y=over_40['high_blood_pressure'],c=over_40['DEATH_EVENT']);

# %%
plt.hist(over_40['DEATH_EVENT'] );
