# %%
import pandas as pn

# %%
ab=pn.read_csv("Ecommerce Purchases")

# %%
ab
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
# display  first 10 rows

# %%
ab.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
# display  last 10 rows

# %%
ab.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
# display  datatypes of  all columns

# %%
ab.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
# checking the missing values in our dataframe
ab.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %%
# checking the total rows and columns in dataset 
len(ab.index)
# Out:
# 10000

# %%
len(ab.columns)
# Out:
# 14

# %%
#second method
ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %%
#find highest and lowest purcahse price
ab['Purchase Price'].min()
# Out:
# 0.0

# %%
ab['Purchase Price'].max()
# Out:
# 99.99

# %%
#find  average purcahse price 
ab['Purchase Price'].mean()
# Out:
# 50.347302

# %%
# how many people have french fr has in their language 
(ab['Language']=='fr').sum()
# Out:
# 1097

# %%
# second method
len(ab[ab['Language']=='fr'])
# Out:
# 1097

# %%
# change the eamil of 9995th person 
ab['Email']
# Out:
# 0                    pdunlap@yahoo.com
# 1                   anthony41@reed.com
# 2       amymiller@morales-harrison.com
# 3          brent16@olson-robinson.info
# 4          christopherwright@gmail.com
#                      ...
# 9995            iscott@wade-garner.com
# 9996                mary85@hotmail.com
# 9997                 tyler16@gmail.com
# 9998           elizabethmoore@reid.net
# 9999             rachelford@vaughn.com
# Name: Email, Length: 10000, dtype: object

# %%
# this is not the professional way , we will change it through loc or iloc 
ab['Email'][9995]='adeelahmedsatt32@gamil.com'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9164\1248121829.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ab['Email'][9995]='adeelahmedsatt32@gamil.com'

# %%
ab['Email'][9995]
# Out:
# 'adeelahmedsatt32@gamil.com'

# %%
# second way of loc
ab.loc[9996]['Email']
# Out:
# 'mary85@hotmail.com'

# %%
ab.loc[9996]['Email']='adeel1293satti@gmil.com'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9164\468456942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ab.loc[9996]['Email']='adeel1293satti@gmil.com'

# %%
ab.loc[9996]['Email']
# Out:
# 'mary85@hotmail.com'

# %%
# how to check the null values in pandas
ab['Purchase Price'].isnull().sum()
# Out:
# 0

# %%
# display job title contain engineer
ab.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ab[ab['Job'].str.contains('engineer',case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
# find the gmail of person whose ip adress is 121.133.168.51
ab[ab['IP Address']=='121.133.168.51']['Email']
# Out:
# 9996    mary85@hotmail.com
# Name: Email, dtype: object

# %%
# how many people used master card as a credit card and their purchase price is greater than 50
ab.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
(ab['Credit Card']=='Mastercard' )&(ab['Purchase Price']>50)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
# find the email of the person of the following credit card number 210033169205009
ab.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
ab[ab['Credit Card']==210033169205009]['Email']
# Out:
# 9996    mary85@hotmail.com
# Name: Email, dtype: object

# %%
# how many people purcahse  during am and pm
ab['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
# how many people have a credit card that expires in 2020
len(ab[ab['CC Exp Date'].str.contains('20')])
# Out:
# 988

# %%
# second method 
ab[ab['CC Exp Date'].apply(lambda x:x [3:]=='20')].count()
# Out:
# Address             988
# Lot                 988
# AM or PM            988
# Browser Info        988
# Company             988
# Credit Card         988
# CC Exp Date         988
# CC Security Code    988
# CC Provider         988
# Email               988
# Job                 988
# IP Address          988
# Language            988
# Purchase Price      988
# dtype: int64

# %%
# third method 
len(ab[ab['CC Exp Date'].apply(lambda x:x [3:]=='20')])
# Out:
# 988

# %%
# top most 5 email provider in the dataset
list1 =[]
for email in ab['Email']:
    list1.append(email.split('@')[1])

# %%
list1
# Out:
# ['yahoo.com',
#  'reed.com',
#  'morales-harrison.com',
#  'olson-robinson.info',
#  'gmail.com',
#  'gmail.com',
#  'yahoo.com',
#  'parks.info',
#  'rasmussen.com',
#  'hunt-huerta.com',
#  'hotmail.com',
#  'coleman.com',
#  'hotmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'yahoo.com',
#  'wilson.com',
#  'hall.com',
#  'yahoo.com',
#  'gmail.com',
#  'smith.info',
#  'hotmail.com',
#  'gmail.com',
#  'gardner-meadows.com',
#  'yahoo.com',
#  'mooney.com',
#  'gmail.com',
#  'hotmail.com',
#  'yahoo.com',
#  'yahoo.com',
#  'hotmail.com',
#  'hotmail.com',
#  'atkinson.com',
#  'yahoo.com',
#  'carey-davis.com',
#  'mcdowell.com',
#  'walsh.com',
#  'frederick.info',
#  'boyd-english.org',
#  'wells-carlson.info',
#  'dickerson.com',
#  'yahoo.com',
#  'gmail.com',
#  'martinez-thomas.com',
#  'yahoo.com',
#  'chambers.com',
#  'gmail.com',
#  'glenn.org',
#  'allen.com',
#  'gmail.com',
#  'obrien.org',
#  'cook-castillo.com',
#  'hotmail.com',
#  'yahoo.com',
#  'hotmail.com',
# ...

# %%
ab['dummay']=list1

# %%
ab.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %%
ab['dummay'].value_counts().head(5)
# Out:
# dummay
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
# second method 
ab['Email'].apply(lambda x:x.split('@')[1]).value_counts().head()
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64

# %%
# %inline matplotlib
import  matplotlib.pyplot as plt 
ab['Purchase Price'].plot()
# Out:
# UsageError: Line magic function `%inline` not found.

# %%
ab['Purchase Price'].plot()
# Out:
# <Axes: >

# %%
ab['Purchase Price'].hist()
# Out:
# <Axes: >
